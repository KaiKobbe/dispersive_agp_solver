# %% [markdown]
# # Random SCOT Generator

# %%
from src.random_scot_generator import RandomOfficeGenerator
from src.visualization import visualize_polygon

generator = RandomOfficeGenerator()

# %%
poly, corridors = generator.random_scot(50)
visualize_polygon(*poly, corridors)

# %%
poly, corridors = generator.random_office(50, hole_free=True)
visualize_polygon(*poly, corridors)
